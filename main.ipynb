# %% [markdown]
# # Desafio do Mini-Curso de Data Science da Dextra

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # IDH Brasil
# As sheets que existem nesse excel:
# - Siglas: explicação das siglas que aparecem nas outras sheets
# - MUN 91-00-10: indicadores de IDH dos municípios nos anos 1991, 2000 e 2010

# %% [markdown]
# File to dataframe:

# %%
PATH_IDH = 'Datasets/Atlas IDH/atlas2013_dadosbrutos_pt.xlsx'
excel_idh = pd.ExcelFile(PATH_IDH)
df_idh_sig = pd.read_excel(excel_idh, 'Siglas')
df_idh_mun = pd.read_excel(excel_idh, 'MUN 91-00-10')

# %% [markdown]
# ### IDH Municípios

# %%
df_idh_mun.head()
# Out:
#     ANO  UF  Codmun6  Codmun7              Município  ESPVIDA  FECTOT  MORT1  \
# 0  1991  11   110001  1100015  ALTA FLORESTA D'OESTE    62.01    4.08  45.58
# 1  1991  11   110002  1100023              ARIQUEMES    66.02    3.72  32.39
# 2  1991  11   110003  1100031                 CABIXI    63.16    3.89  41.52
# 3  1991  11   110004  1100049                 CACOAL    65.03    3.81  35.37
# 4  1991  11   110005  1100056             CEREJEIRAS    62.73    3.55  43.00
#
#    MORT5  RAZDEP  SOBRE40  SOBRE60  T_ENV  E_ANOSESTUDO  T_ANALF11A14  \
# 0  58.05   73.50    83.81    66.87   1.82          6.68          9.74
# 1  41.41   69.97    88.08    74.23   1.82          7.86          9.35
# 2  52.94   77.23    85.09    69.00   2.59          7.43          9.62
# 3  45.19   71.11    87.08    72.44   2.47          8.34          6.32
# 4  54.82   71.09    84.62    68.20   2.46          8.14          5.06
#
#    T_ANALF15A17  T_ANALF15M  T_ANALF18A24  T_ANALF18M  T_ANALF25A29  \
# ...

# %% [markdown]
# ### Siglas IDH

# %%
df_idh_sig.count()
# Out:
# SIGLA         237
# NOME CURTO    237
# NOME LONGO    237
# DEFINIÇÃO     237
# dtype: int64

# %%
df_idh_sig.head(10)
# Out:
#      SIGLA                       NOME CURTO  \
# 0       UF   Código da Unidade da Federação
# 1      UFN     Nome da Unidade da Federação
# 2  CODMUN6              Código do Município
# 3  CODMUN7              Código do Município
# 4  NOMEMUN                Nome do Município
# 5  ESPVIDA     Esperança de vida ao nascer
# 6   FECTOT        Taxa de fecundidade total
# 7    MORT1             Mortalidade infantil
# 8    MORT5  Mortalidade até 5 anos de idade
# 9   RAZDEP             Razão de dependência
#
#                                                                                                             NOME LONGO  \
# 0                                                                                       Código da Unidade da Federação
# 1                                                                                         Nome da Unidade da Federação
# 2                                                                                                  Código do Município
# ...

# %% [markdown]
# *Some important abbreviations:*

# %%
df_idh_sig[df_idh_sig['SIGLA'] == 'IDHM']
# Out:
#     SIGLA NOME CURTO                                  NOME LONGO  \
# 233  IDHM       IDHM  Índice de Desenvolvimento Humano Municipal
#
#                                                                                                                                    DEFINIÇÃO
# 233  Índice de Desenvolvimento Humano Municipal. Média geométrica dos índices das dimensões Renda, Educação e Longevidade, com pesos iguais.

# %%
df_idh_sig[df_idh_sig['SIGLA'] == 'IDHM_R']
# Out:
#       SIGLA  NOME CURTO  \
# 236  IDHM_R  IDHM Renda
#
#                                                       NOME LONGO  \
# 236  Índice de Desenvolvimento Humano Municipal - Dimensão Renda
#
#                                                                                                                                                                                                                                                                                                                          DEFINIÇÃO
# 236  Índice da dimensão Renda que é um dos 3 componentes do IDHM. É obtido a partir do indicador Renda per capita, através da fórmula: [ln (valor observado do indicador) - ln (valor mínimo)] / [ln (valor máximo) - ln (valor mínimo)], onde os valores mínimo e máximo são R$ 8,00 e R$ 4.033,00 (a preços de agosto de 2010).

# %%
df_idh_sig[df_idh_sig['SIGLA'] == 'IDHM_L']
# Out:
#       SIGLA        NOME CURTO  \
# 235  IDHM_L  IDHM Longevidade
#
#                                                              NOME LONGO  \
# 235  Índice de Desenvolvimento Humano Municipal  - Dimensão Longevidade
#
#                                                                                                                                                                                                                                                                                                          DEFINIÇÃO
# 235  Índice da dimensão Longevidade que é um dos 3 componentes do IDHM. É obtido a partir do indicador Esperança de vida ao nascer, através da fórmula: [(valor observado do indicador) - (valor mínimo)] / [(valor máximo) - (valor mínimo)], onde os valores mínimo e máximo são 25 e 85 anos, respectivamente.

# %%
df_idh_sig[df_idh_sig['SIGLA'] == 'IDHM_E']
# Out:
# Empty DataFrame
# Columns: [SIGLA, NOME CURTO, NOME LONGO, DEFINIÇÃO]
# Index: []

# %% [markdown]
# Apesar de não estar incluído nas siglas, IDHM_E representa o último componente do IDHM (seguindo a nomenclatura dos dois componentes anteriores): a Educação.

# %% [markdown]
# *Um estudo básico sobre o IDH brasileiro. Vamos levantar algumas perguntas/hipóteses:*

# %% [markdown]
# ## O IDH brasileiro melhorou? Foi um crescimento uniforme nos três componentes?

# %%
amnt_null_idh = df_idh_mun[df_idh_mun['IDHM'].isnull()].count()[0]
amnt_null_educ = df_idh_mun[df_idh_mun['IDHM_E'].isnull()].count()[0]
amnt_null_longev = df_idh_mun[df_idh_mun['IDHM_L'].isnull()].count()[0]
amnt_null_renda = df_idh_mun[df_idh_mun['IDHM_R'].isnull()].count()[0]
amnt_null_idh + amnt_null_educ + amnt_null_longev + amnt_null_renda
# Out:
# 0

# %% [markdown]
# *Não há nenhum valor nulo no DataFrame nas colunas IDHM, IDHM_E, IDHM_R, IDHM_L*

# %%
df_idh_mun[df_idh_mun['IDHM']==0].count()[0]
null_idh = df_idh_mun.count()[0] - df_idh_mun[df_idh_mun['IDHM'].notnull()].count()[0]
null_educ = df_idh_mun.count()[0] - df_idh_mun[df_idh_mun['IDHM_E'].notnull()].count()[0]
null_renda = df_idh_mun.count()[0] - df_idh_mun[df_idh_mun['IDHM_R'].notnull()].count()[0]
null_longev = df_idh_mun.count()[0] - df_idh_mun[df_idh_mun['IDHM_L'].notnull()].count()[0]

null_educ + null_renda + null_educ + null_idh
# Out:
# 0

# %%
gp_idh_mean_year = df_idh_mun.groupby('ANO')[['IDHM', 'IDHM_R', 'IDHM_E', 'IDHM_L']].mean()
gp_idh_mean_year.columns = ['IDH', 'renda', 'educ', 'longev']
gp_idh_mean_year.head()
# Out:
#            IDH     renda      educ    longev
# ANO
# 1991  0.381372  0.514515  0.178705  0.645658
# 2000  0.523481  0.575718  0.354197  0.723611
# 2010  0.659157  0.642873  0.559094  0.801564

# %%
gp_idh_mean_year[['IDH']].plot()
gp_idh_mean_year[['renda', 'educ', 'longev']].plot()

# %% [markdown]
# Podemos observar que o IDH brasileiro melhorou durante os três últimos censos se aproximando muito de uma reta e o indicador que mais aumentou nesse período foi o de educação.

# %%
df_idh_mean_year = gp_idh_mean_year.reset_index()

idh_1991 = df_idh_mean_year[df_idh_mean_year['ANO']==1991]
idh_2010 = df_idh_mean_year[df_idh_mean_year['ANO']==2010]

# %%
data_idh_increased_abs = {
    'aumento abs IDH':  [idh_2010['IDH'].item() - idh_1991['IDH'].item()],
    'aumento abs Renda':  [idh_2010['renda'].item() - idh_1991['renda'].item()],
    'aumento abs Educacao':  [idh_2010['educ'].item() - idh_1991['educ'].item()],
    'aumento abs Longevidade':  [idh_2010['longev'].item() - idh_1991['longev'].item()],
}
pd.DataFrame(data_idh_increased_abs)
# Out:
#    aumento abs IDH  aumento abs Renda  aumento abs Educacao  \
# 0         0.277785           0.128358              0.380389
#
#    aumento abs Longevidade
# 0                 0.155906

# %%
data_idh_increased_abs = {
    'aumento IDH (%)': [(idh_2010['IDH'].item()/idh_1991['IDH'].item()-1)*100],
    'aumento Renda (%)': [(idh_2010['renda'].item()/idh_1991['renda'].item()-1)*100],
    'aumento Educacao (%)': [(idh_2010['educ'].item()/idh_1991['educ'].item()-1)*100],
    'aumento Longevidade (%)': [(idh_2010['longev'].item()/idh_1991['longev'].item()-1)*100],
}
pd.DataFrame(data_idh_increased_abs)
# Out:
#    aumento IDH (%)  aumento Renda (%)  aumento Educacao (%)  \
# 0        72.838291          24.947403            212.858713
#
#    aumento Longevidade (%)
# 0                24.146827

# %% [markdown]
# Novamente podemos observar que o indicador que teve mais aumento absoluto e percentual foi o de educação. Os outros 2 tiveram um aumento mediano e bem próximos.
# Dessa forma, o que mais influenciou o crescimento do IDH nesse período foi a melhoria na educação.
# Mesmo assim, esse componente ainda é o menor dentre os três.

# %% [markdown]
# ## Há uma relação entre Renda e Educação?

# %% [markdown]
# A coluna UFN (nome de cada estado) não está presente no dataframe como dizia então busquei um dataframe que contém a relação de código dos estados, nome e sigla. Então podemos fazer um merge dos dataframes.

# %%
PATH_CODIGO_ESTADOS = 'Datasets/Codigos-UF/codigos_uf.csv'
df_codigo_estados = pd.read_csv(PATH_CODIGO_ESTADOS, sep=r'\s*,\s*', header=0, engine='python')
df_codigo_estados.head()
# Out:
#    Codigo       UFN  UF
# 0      11  Rondônia  RO
# 1      12      Acre  AC
# 2      13  Amazonas  AM
# 3      14   Roraima  RR
# 4      15      Pará  PA

# %%
df_idh_mun['UFN'] = df_idh_mun['UF'].map(lambda codigo: df_codigo_estados[df_codigo_estados['Codigo']==codigo]['UFN'].item())
df_idh_mun['UF'] = df_idh_mun['UF'].map(lambda codigo: df_codigo_estados[df_codigo_estados['Codigo']==codigo]['UF'].item())
df_idh_mun[['UF', 'UFN']].head()
# Out:
#    UF       UFN
# 0  RO  Rondônia
# 1  RO  Rondônia
# 2  RO  Rondônia
# 3  RO  Rondônia
# 4  RO  Rondônia

# %%
df_idh_est = df_idh_mun[df_idh_mun['ANO']==2010].groupby('UF')[['IDHM', 'IDHM_R', 'IDHM_E', 'IDHM_L']].mean()
df_idh_est.head()
# Out:
#         IDHM    IDHM_R    IDHM_E    IDHM_L
# UF
# AC  0.586091  0.585455  0.452227  0.766591
# AL  0.563500  0.548363  0.442745  0.739539
# AM  0.565113  0.545113  0.436935  0.765548
# AP  0.642813  0.618875  0.549937  0.783938
# BA  0.593904  0.574743  0.481887  0.759583

# %%
df_idh_correl = df_idh_est[['IDHM_E', 'IDHM_R']].sort_values('IDHM_R')
df_idh_correl.plot.bar(figsize=(15, 10))

# %%
df_idh_correl.head()
# Out:
#       IDHM_E    IDHM_R
# UF
# MA  0.488622  0.531664
# AM  0.436935  0.545113
# PI  0.456692  0.546813
# AL  0.442745  0.548363
# CE  0.552120  0.559293

# %%
import seaborn as sns

# %%
sns.scatterplot(df_idh_correl['IDHM_E'], df_idh_correl['IDHM_R'])

# %% [markdown]
# Podemos observar que esses pontos seguem, mesmo que de forma não tão forte e precisa, uma reta crescente. Levando a entender que as duas medidas se comportam de maneira diretamente proporcional.

# %% [markdown]
# Para confirmar essa suposição vamos utilizar a função correlation pois estamos lidando com dois dados quantitativos.

# %%
df_idh_correl['IDHM_E'].corr(df_idh_correl['IDHM_R'])
# Out:
# 0.9249295379582392

# %% [markdown]
# Então realmente uma alta correlação.

# %% [markdown]
# #### Poderíamos também verificar a correlação entre os outros e observer qual eram os componentes mais correlacionados entre renda, longevidade e educação.

# %% [markdown]
# # Finbra
# Esses dados representam dados financeiros das cidades brasileiras e incluem informações como receitas e despesas gerais.

# %%
PATH_FINBRA_DO = 'Datasets/Finbra/finbra_do_consolidado.csv'
df_despesas = pd.read_csv(PATH_FINBRA_DO, sep=r'\s*,\s*', header=0, engine='python')
df_despesas.head()
# Out:
#                                         instituição  cod.ibge    ibge  uf  \
# 0      Prefeitura Municipal de Abadia de Goiás - GO   5200050  520005  GO
# 1  Prefeitura Municipal de Abadia dos Dourados - MG   3100104  310010  MG
# 2            Prefeitura Municipal de Abadiânia - GO   5200100  520010  GO
# 3           Prefeitura Municipal de Abaetetuba - PA   1500107  150010  PA
# 4               Prefeitura Municipal de Abaeté - MG   3100203  310020  MG
#
#    população   ano  3.0.00.00.00.00 Despesas Correntes  \
# 0       8053  2018                        3.064559e+07
# 1       7059  2018                        1.848571e+07
# 2      18427  2018                        3.981528e+07
# 3     151934  2018                        2.313475e+08
# 4      23574  2018                        4.187331e+07
#
#    3.1.00.00.00.00 Pessoal e Encargos Sociais  \
# 0                                1.813997e+07
# 1                                1.087266e+07
# ...

# %%
PATH_FINBRA_RO = 'Datasets/Finbra/finbra_ro_consolidado.csv'
df_receitas = pd.read_csv(PATH_FINBRA_RO, sep=r'\s*,\s*', header=0, engine='python')
df_receitas.head(1)
# Out:
#                                     instituição  cod.ibge    ibge  uf  \
# 0  Prefeitura Municipal de Abadia de Goiás - GO   5200050  520005  GO
#
#    população   ano  0.0.0.0.00.00.00 TT Receita  \
# 0       7567  2013                  22517288.98
#
#    1.0.0.0.00.00.00 Receita Corrente  1.1.0.0.00.00.00 Receita Tributária  \
# 0                        20435709.16                           1696592.64
#
#    1.1.2.0.00.00.00 Taxas  1.1.3.0.00.00.00 Contribuições de Melhoria  \
# 0               308713.08                                         0.0
#
#    1.2.0.0.00.00.00 Contribuições Sociais e Custeio  \
# 0                                          10106.45
#
#    1.3.0.0.00.00.00 Receita Patrimonial  \
# 0                             326673.75
#
#    "1.6.0.0.00.00.00 Receita de Serviços Administrativos  \
# 0                                                    0.0
#
#    Comerciais e Transporte"  1.7.0.0.00.00.00 Transfêrencias Corrente  \
# ...

# %%
df_receitas[['população', 'ano']].groupby('ano').sum().head()
# Out:
#       população
# ano
# 2013  197201936
# 2014  191902661
# 2015  197225666
# 2016  198246603
# 2017  202193162

# %%
df_despesas[['população', 'ano']].groupby('ano').sum().head()
# Out:
#       população
# ano
# 2013  195266041
# 2014  190782379
# 2015  196823198
# 2016  197969734
# 2017  202180153

# %% [markdown]
# Temos as informações dos anos 2013 a 2017

# %% [markdown]
# Preparando dataframe...

# %%
df_finbra_tudo = pd.merge(df_despesas, df_receitas, on=['ano', 'instituição', 'cod.ibge', 'ibge', 'uf'])

df_finbra_geral = pd.DataFrame({'instituicao': df_finbra_tudo['instituição']})
df_finbra_geral['populacao'] = (df_finbra_tudo['população_x'] + df_finbra_tudo['população_y']) / 2
df_finbra_geral['receita_total'] = df_finbra_tudo['1.0.0.0.00.00.00 Receita Corrente']
df_finbra_geral['despesa_total'] = df_finbra_tudo['3.0.00.00.00.00 Despesas Correntes']
df_finbra_geral['ano'] = df_finbra_tudo['ano']
df_finbra_geral['uf'] = df_finbra_tudo['uf']
df_finbra_geral.head()
# Out:
#                                         instituicao  populacao  receita_total  \
# 0      Prefeitura Municipal de Abadia de Goiás - GO     8053.0   3.238217e+07
# 1  Prefeitura Municipal de Abadia dos Dourados - MG     7059.0   1.948697e+07
# 2            Prefeitura Municipal de Abadiânia - GO    18427.0   3.979113e+07
# 3           Prefeitura Municipal de Abaetetuba - PA   151934.0   2.506197e+08
# 4               Prefeitura Municipal de Abaeté - MG    23574.0   4.153957e+07
#
#    despesa_total   ano  uf
# 0   3.064559e+07  2018  GO
# 1   1.848571e+07  2018  MG
# 2   3.981528e+07  2018  GO
# 3   2.313475e+08  2018  PA
# 4   4.187331e+07  2018  MG

# %% [markdown]
# # Mi Social
# Esse dados representam informações de famílias em pobreza e extrema pobreza.

# %%
PATH_MI_SOCIAL = 'Datasets/MISocial/misocial.csv'
df_misocial = pd.read_csv(PATH_MI_SOCIAL, sep=r'\s*,\s*', header=0, engine='python')
df_misocial.head()
# Out:
#    Unnamed: 0    ibge  anomes  cadunico_tot_fam  cadunico_tot_pes  \
# 0           0  110001  201401            4406.0           14609.0
# 1           1  110002  201401           12988.0           42365.0
# 2           2  110003  201401             980.0            3217.0
# 3           3  110004  201401            9510.0           31521.0
# 4           4  110005  201401            2360.0            8018.0
#
#    cadunico_tot_fam_rpc_ate_meio_sm  cadunico_tot_pes_rpc_ate_meio_sm  \
# 0                            3840.0                           13702.0
# 1                           11533.0                           39853.0
# 2                             921.0                            3123.0
# 3                            8269.0                           28942.0
# 4                            2250.0                            7810.0
#
#    cadunico_tot_fam_pob  cadunico_tot_pes_pob  cadunico_tot_fam_ext_pob  \
# ...

# %% [markdown]
# Preparando os dados...

# %%
df_misocial_prepared = pd.DataFrame({'ibge': df_misocial['ibge']})
df_misocial_prepared['total_fam'] = df_misocial['cadunico_tot_fam']
df_misocial_prepared['total_pes'] = df_misocial['cadunico_tot_pes']
df_misocial_prepared['total_fam_pob'] = df_misocial['cadunico_tot_fam_pob']
df_misocial_prepared['total_pes_pob'] = df_misocial['cadunico_tot_pes_pob']
df_misocial_prepared['total_fam_ext_pob'] = df_misocial['cadunico_tot_fam_ext_pob']
df_misocial_prepared['total_pes_ext_pob'] = df_misocial['cadunico_tot_pes_ext_pob']
df_misocial_prepared.head()
# Out:
#      ibge  total_fam  total_pes  total_fam_pob  total_pes_pob  \
# 0  110001     4406.0    14609.0         1108.0         4103.0
# 1  110002    12988.0    42365.0         3830.0        14272.0
# 2  110003      980.0     3217.0          274.0          990.0
# 3  110004     9510.0    31521.0         2648.0        10126.0
# 4  110005     2360.0     8018.0          866.0         3101.0
#
#    total_fam_ext_pob  total_pes_ext_pob
# 0             2031.0             7355.0
# 1             4784.0            16618.0
# 2              382.0             1261.0
# 3             2606.0             9143.0
# 4              896.0             3154.0

# %% [markdown]
# ---

# %% [markdown]
# # Covid
# Dados do covid no Brasil. Datasets:
# - Dados de casos acumulados e óbtidos por município e por dia. Disponível em: https://covid.saude.gov.br/.
# - Dados dos pacientes de Covid19. Disponível em: https://brasil.io/dataset/covid19/caso_full/.
#
# Os dados são os mais atualizados até 19 de maio.

# %%
PATH_COVID_CASOS = 'Datasets/covid19/HIST_PAINEL_COVIDBR_19mai2020.xlsx'
df_casos = pd.read_excel(pd.ExcelFile(PATH_COVID_CASOS))
df_casos.head()
# Out:
#    regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
#          data  semanaEpi  populacaoTCU2019  casosAcumulado  obitosAcumulado  \
# 0  2020-02-26          9       210147125.0               1                0
# 1  2020-02-27          9       210147125.0               1                0
# 2  2020-02-28          9       210147125.0               1                0
# 3  2020-02-29          9       210147125.0               2                0
# 4  2020-03-01         10       210147125.0               2                0
#
#    Recuperadosnovos  emAcompanhamentoNovos
# ...

# %%
df_casos['coduf'].notnull().mean()
# Out:
# 1.0

# %% [markdown]
# Temos algumas linhas sem município e codmun, porém todos as linhas tem a informação do estado pelo coduf.

# %%
df_cod_estados = df_casos[df_casos['estado'].notnull()][['coduf', 'estado']].groupby('coduf').first()
df_cod_estados = df_cod_estados.reset_index()
df_cod_estados
# Out:
#     coduf estado
# 0      11     RO
# 1      12     AC
# 2      13     AM
# 3      14     RR
# 4      15     PA
# 5      16     AP
# 6      17     TO
# 7      21     MA
# 8      22     PI
# 9      23     CE
# 10     24     RN
# 11     25     PB
# 12     26     PE
# 13     27     AL
# 14     28     SE
# 15     29     BA
# 16     31     MG
# 17     32     ES
# 18     33     RJ
# 19     35     SP
# 20     41     PR
# 21     42     SC
# 22     43     RS
# 23     50     MS
# 24     51     MT
# 25     52     GO
# 26     53     DF

# %%
df_casos.groupby('coduf')['estado'].agg(['first', 'count'])
# Out:
#       first  count
# coduf
# 11       RO    883
# 12       AC    550
# 13       AM   1921
# 14       RR    522
# 15       PA   3813
# 16       AP    542
# 17       TO   1064
# 21       MA   3759
# 22       PI   2281
# 23       CE   5678
# 24       RN   3003
# 25       PB   2535
# 26       PE   5023
# 27       AL   1744
# 28       SE   1430
# 29       BA   6102
# 31       MG   8220
# 32       ES   2274
# 33       RJ   3616
# 35       SP  13883
# 41       PR   5784
# 42       SC   5708
# 43       RS   6510
# 50       MS   1126
# 51       MT   1571
# 52       GO   2634
# 53       DF    127
# 76      NaN      0

# %% [markdown]
# Por algum motivo há um código 76, porém não existe nenhum estado com esse código, então vamos removê-lo.

# %%
df_casos = df_casos[df_casos['coduf']!=76]

# %% [markdown]
# Agora vamos adicionar o nome dos estados a todos os que estão com o nome nulo.

# %%
df_casos = df_casos.reset_index()
del df_casos['index']

def estado_from_cod(cod) :
    return df_cod_estados[df_cod_estados['coduf']==cod]['estado'].item()
df_casos['estado'] = df_casos.apply(lambda x: estado_from_cod(x['coduf']), axis=1)

df_casos = df_casos.reset_index()
df_casos.head()
# Out:
#    index regiao estado municipio  coduf  codmun  codRegiaoSaude  \
# 0      0  Norte     RO       NaN     11     NaN             NaN
# 1      1  Norte     RO       NaN     11     NaN             NaN
# 2      2  Norte     RO       NaN     11     NaN             NaN
# 3      3  Norte     RO       NaN     11     NaN             NaN
# 4      4  Norte     RO       NaN     11     NaN             NaN
#
#   nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  casosAcumulado  \
# 0             NaN  2020-03-20         12         1777225.0               1
# 1             NaN  2020-03-21         12         1777225.0               1
# 2             NaN  2020-03-22         13         1777225.0               3
# 3             NaN  2020-03-23         13         1777225.0               3
# 4             NaN  2020-03-24         13         1777225.0               3
#
#    obitosAcumulado  Recuperadosnovos  emAcompanhamentoNovos
# 0                0               NaN                    NaN
# ...

# %% [markdown]
# Todos os municípios estão com os dados atualizados até o mesmo dia?

# %%
df_casos_not_nan_mun = df_casos[df_casos['codmun'].notnull()]

from functools import reduce
def ultimaAtualizacao(series) :
    return reduce(lambda x,y: x if x>y else y, series)
last_update_mun = df_casos_not_nan_mun.groupby('codmun').agg({'data': [ultimaAtualizacao]})
last_update_mun = last_update_mun.reset_index()
last_update_mun
# Out:
#         codmun              data
#                ultimaAtualizacao
# 0     110000.0        2020-05-16
# 1     110001.0        2020-05-19
# 2     110002.0        2020-05-19
# 3     110004.0        2020-05-19
# 4     110009.0        2020-05-19
# ...        ...               ...
# 3472  522160.0        2020-05-19
# 3473  522180.0        2020-04-27
# 3474  522185.0        2020-05-19
# 3475  522200.0        2020-05-19
# 3476  530010.0        2020-05-19
#
# [3477 rows x 2 columns]

# %%
last_update_mun['ultimaAtualizacao'] = last_update_mun[('data', 'ultimaAtualizacao')]
del last_update_mun[('data', 'ultimaAtualizacao')]
last_update_mun.groupby('ultimaAtualizacao').count()
# Out:
#                   codmun
#
# ultimaAtualizacao
# 2020-03-28             1
# 2020-04-01             1
# 2020-04-12             1
# 2020-04-16             1
# 2020-04-18             1
# 2020-04-20             2
# 2020-04-22             1
# 2020-04-27             1
# 2020-04-28             4
# 2020-04-29             1
# 2020-04-30             1
# 2020-05-01             1
# 2020-05-04             3
# 2020-05-06             2
# 2020-05-07             5
# 2020-05-08             3
# 2020-05-09             4
# 2020-05-11             1
# 2020-05-12             5
# 2020-05-13             4
# 2020-05-14             5
# 2020-05-15             6
# 2020-05-16             5
# 2020-05-17             3
# 2020-05-18             4
# 2020-05-19          3411

# %% [markdown]
# Praticamente todas as cidades foram atualizadas pela última vez no dia 19/05, então não precisaremos desconsiderar nenhum dia.

# %% [markdown]
# Fazendo a consulta abaixo e comparando com os dados oficiais no site do governo percebi que por algum motivo o resultado da consulta no dataframe resultou exatamente no dobro do número de casos acumulados no site do governo (casos acumulados: 271.628, óbitos acumulados: 17.971). E o mesmo aconteceu com o número de óbtidos. Observe as consultas abaixo:

# %%
df_casos[df_casos['data']=='2020-05-19']['casosAcumulado'].sum()
# Out:
# 543256

# %%
df_casos[df_casos['data']=='2020-05-19']['obitosAcumulado'].sum()
# Out:
# 35942

# %% [markdown]
# Então vamos analisar a frequência de rows por dia por município para saber se os dados do governo não estão sendo incluídos por exemplo duas vezes gerando esse resultado.

# %%
gb_data_mun = df_casos_not_nan_mun[['casosAcumulado', 'data', 'codmun']].copy()
gb_data_mun['group'] = gb_data_mun['codmun'].astype(str) + gb_data_mun['data']
df_data_mun = gb_data_mun.groupby('group').agg({'data': ['count']}).reset_index()

df_data_mun['count'] = df_data_mun[('data', 'count')]
del df_data_mun[('data', 'count')]
df_data_mun
# Out:
#                     group count
#
# 0      110000.02020-04-23     1
# 1      110000.02020-04-30     1
# 2      110000.02020-05-16     1
# 3      110001.02020-05-02     1
# 4      110001.02020-05-03     1
# ...                   ...   ...
# 90483  530010.02020-05-15     1
# 90484  530010.02020-05-16     1
# 90485  530010.02020-05-17     1
# 90486  530010.02020-05-18     1
# 90487  530010.02020-05-19     1
#
# [90488 rows x 2 columns]

# %%
df_data_mun['all'] = True
df_data_mun.groupby('all').max()
# Out:
#                    group count
#
# all
# True  530010.02020-05-19     1

# %% [markdown]
# Todos os municípios tem no máximo 1 row por dia, então não é isso que está gerando o resultado dobrado.

# %% [markdown]
# E os municípios Nan que não foram considerados? Será que esse resultado por ter a ver com isso?

# %%
df_casos_nan_mun = df_casos[df_casos['codmun'].isna()]
df_casos_nan_mun
# Out:
#       index        regiao estado municipio  coduf  codmun  codRegiaoSaude  \
# 0         0         Norte     RO       NaN     11     NaN             NaN
# 1         1         Norte     RO       NaN     11     NaN             NaN
# 2         2         Norte     RO       NaN     11     NaN             NaN
# 3         3         Norte     RO       NaN     11     NaN             NaN
# 4         4         Norte     RO       NaN     11     NaN             NaN
# ...     ...           ...    ...       ...    ...     ...             ...
# 1810   1810  Centro-Oeste     DF       NaN     53     NaN             NaN
# 1811   1811  Centro-Oeste     DF       NaN     53     NaN             NaN
# 1812   1812  Centro-Oeste     DF       NaN     53     NaN             NaN
# 1813   1813  Centro-Oeste     DF       NaN     53     NaN             NaN
# 1814   1814  Centro-Oeste     DF       NaN     53     NaN             NaN
#
#      nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  casosAcumulado  \
# ...

# %%
print(df_casos_nan_mun[df_casos_nan_mun['data']=='2020-05-19']['casosAcumulado'].sum())
print(df_casos_not_nan_mun[df_casos_not_nan_mun['data']=='2020-05-19']['casosAcumulado'].sum())
# Out:
# 271628
# 271628

# %%
df_comparacao_mun = df_casos.copy()
df_comparacao_mun['mun_is_nan'] = df_comparacao_mun['codmun'].isna()
df_comparacao_mun.groupby('mun_is_nan').sum()
# Out:
#                  index    coduf        codmun  codRegiaoSaude  semanaEpi  \
# mun_is_nan
# False       4258229548  2838375  2.850993e+10    2.823955e+09    1661548
# True           1646205    53771  0.000000e+00    0.000000e+00      29205
#
#             populacaoTCU2019  casosAcumulado  obitosAcumulado  \
# mun_is_nan
# False           8.297478e+09         4251320           284004
# True            1.521489e+10         4266782           284025
#
#             Recuperadosnovos  emAcompanhamentoNovos
# mun_is_nan
# False                    0.0                    0.0
# True                     0.0                    0.0

# %%
df_comparacao_mun.groupby('mun_is_nan')['data'].count()
# Out:
# mun_is_nan
# False    90488
# True      1815
# Name: data, dtype: int64

# %% [markdown]
# O que podemos observar é que os dados estão praticamente duplicados quando em codmun==nan e codmun!=nan. Na construção do dataset, o governo pode ter adicionado as rows com campo codmun NaN por ser o resultado total de cada estado (somando as informações de cada cidade). De qualquer forma, vamos remover as informacoes em que codmun==nan pois não nos acrescenta nenhuma informação, apenas dificulta as transformações.

# %%
df_casos = df_casos[df_casos['codmun'].notnull()]
df_casos[df_casos['codmun'].isna()].count()
# Out:
# index                    0
# regiao                   0
# estado                   0
# municipio                0
# coduf                    0
# codmun                   0
# codRegiaoSaude           0
# nomeRegiaoSaude          0
# data                     0
# semanaEpi                0
# populacaoTCU2019         0
# casosAcumulado           0
# obitosAcumulado          0
# Recuperadosnovos         0
# emAcompanhamentoNovos    0
# dtype: int64

# %% [markdown]
# Vamos analisar as colunas Recuperadosnovos e emAcompanhamentoNovos:

# %%
df_casos[df_casos['Recuperadosnovos'].notnull()]
# Out:
# Empty DataFrame
# Columns: [index, regiao, estado, municipio, coduf, codmun, codRegiaoSaude, nomeRegiaoSaude, data, semanaEpi, populacaoTCU2019, casosAcumulado, obitosAcumulado, Recuperadosnovos, emAcompanhamentoNovos]
# Index: []

# %%
df_casos[df_casos['emAcompanhamentoNovos'].notnull()]
# Out:
# Empty DataFrame
# Columns: [index, regiao, estado, municipio, coduf, codmun, codRegiaoSaude, nomeRegiaoSaude, data, semanaEpi, populacaoTCU2019, casosAcumulado, obitosAcumulado, Recuperadosnovos, emAcompanhamentoNovos]
# Index: []

# %% [markdown]
# Todos os dados dessas colunas são nulas então elas serão removidas do dataframe.

# %%
del df_casos['emAcompanhamentoNovos']
del df_casos['Recuperadosnovos']

# %% [markdown]
# # Mortes e casos acumulados do Brasil

# %%
df_casos[['casosAcumulado', 'obitosAcumulado', 'data']].groupby('data').sum().plot()

# %%
df_total_acumulados = df_casos[df_casos['data']=='2020-05-19'][['estado', 'casosAcumulado', 'obitosAcumulado']]
df_total_acumulados['all'] = True
df_total_acumulados.groupby('all').sum()
# Out:
#       casosAcumulado  obitosAcumulado
# all
# True          271628            17971

# %% [markdown]
# # Óbitos e casos acumulados por estado

# %%
df_dados_estado = df_casos[['casosAcumulado', 'obitosAcumulado', 'estado', 'data']].groupby(['estado', 'data']).sum().reset_index()

# %% [markdown]
# ### Casos acumulados por estado

# %%
df_dados_estado.pivot(index='data', columns='estado', values='casosAcumulado').plot()
plt.legend(loc=(1.04,0))

# %% [markdown]
# ### Óbitos acumulados por estado

# %%
df_dados_estado.pivot(index='data', columns='estado', values='obitosAcumulado').plot()
plt.legend(loc=(1.04,0))

# %% [markdown]
# # Óbitos e casos acumulados percentualmente por estado

# %%
df_populacao_por_estado = df_casos.groupby('estado').first().reset_index()[['estado', 'coduf', 'populacaoTCU2019']]
df_populacao_por_estado.head()
# Out:
#   estado  coduf  populacaoTCU2019
# 0     AC     12          881935.0
# 1     AL     27         3337357.0
# 2     AM     13         4144597.0
# 3     AP     16          845731.0
# 4     BA     29        14873064.0

# %%
def populacao_from_cod(estado) :
    return series_populacao_por_estado[series_populacao_por_estado['estado']==estado]['populacaoTCU2019'].item()

# %% [markdown]
# ## Casos

# %%
df_dados_estado['casosAcumuladoPor10Mil'] = df_dados_estado.apply(lambda x: 10000 * x['casosAcumulado'] / populacao_from_cod(x['estado']), axis=1)
df_dados_estado.head()
# Out:
#   estado        data  casosAcumulado  obitosAcumulado  casosAcumuladoPerc  \
# 0     AC  2020-03-28              25                0            0.000028
# 1     AC  2020-03-29              34                0            0.000039
# 2     AC  2020-03-30              42                0            0.000048
# 3     AC  2020-03-31              42                0            0.000048
# 4     AC  2020-04-01              43                0            0.000049
#
#    casosAcumuladoPorMil  casosAcumuladoPor10Mil
# 0              0.028347                0.283468
# 1              0.038552                0.385516
# 2              0.047623                0.476226
# 3              0.047623                0.476226
# 4              0.048756                0.487564

# %%
df_dados_estado.pivot(index='data', columns='estado', values='casosAcumuladoPor10Mil').plot()
plt.legend(loc=(1.04,0))

# %% [markdown]
# ## Óbitos

# %%
df_dados_estado['obitosAcumuladoPor10Mil'] = df_dados_estado.apply(lambda x: 10000 * x['obitosAcumulado'] / populacao_from_cod(x['estado']), axis=1)
df_dados_estado.head()
# Out:
#   estado        data  casosAcumulado  obitosAcumulado  casosAcumuladoPerc  \
# 0     AC  2020-03-28              25                0            0.000028
# 1     AC  2020-03-29              34                0            0.000039
# 2     AC  2020-03-30              42                0            0.000048
# 3     AC  2020-03-31              42                0            0.000048
# 4     AC  2020-04-01              43                0            0.000049
#
#    casosAcumuladoPorMil  casosAcumuladoPor10Mil  obitosAcumuladoPor10Mil
# 0              0.028347                0.283468                      0.0
# 1              0.038552                0.385516                      0.0
# 2              0.047623                0.476226                      0.0
# 3              0.047623                0.476226                      0.0
# 4              0.048756                0.487564                      0.0

# %%
df_dados_estado.pivot(index='data', columns='estado', values='obitosAcumuladoPor10Mil').plot()
plt.legend(loc=(1.04,0))

# %% [markdown]
# # Leitos de UTI

# %%
PATH_LEITOS_INTERNACAO = 'Datasets/covid19/leitos_internacao.csv'
df_leitos_internacao = pd.read_csv(PATH_LEITOS_INTERNACAO, sep=r'\s*;\s*', header=0, engine='python')
df_leitos_internacao

df_leitos_internacao[['UF', 'qtd']] = df_leitos_internacao[['"UF"', '"Quantidade_existente"']]
del df_leitos_internacao['"UF"']
del df_leitos_internacao['"Quantidade_existente"']

df_leitos_internacao['cod'] = df_leitos_internacao['UF'].str[1:3]
df_leitos_internacao['UF'] = df_leitos_internacao['UF'].str[4:-1]
df_leitos_internacao
# Out:
#                      UF    qtd cod
# 0              Rondonia   4286  11
# 1                  Acre   1484  12
# 2              Amazonas   5700  13
# 3               Roraima   1133  14
# 4                  Para  13584  15
# 5                 Amapa   1098  16
# 6             Tocantins   3072  17
# 7              Maranhao  13778  21
# 8                 Piaui   7460  22
# 9                 Ceara  18510  23
# 10  Rio Grande do Norte   7272  24
# 11              Paraiba   8171  25
# 12           Pernambuco  20961  26
# 13              Alagoas   5891  27
# 14              Sergipe   3212  28
# 15                Bahia  28960  29
# 16         Minas Gerais  40699  31
# 17       Espirito Santo   7929  32
# 18       Rio de Janeiro  32736  33
# 19            Sao Paulo  90603  35
# 20               Parana  27502  41
# 21       Santa Catarina  15322  42
# 22    Rio Grande do Sul  30123  43
# 23   Mato Grosso do Sul   5596  50
# 24          Mato Grosso   7156  51
# 25                Goias  17445  52
# ...

# %% [markdown]
# ## Adicionando leitos de UTI

# %%
for estado in df_cod_estados['estado']:
    df = df_dados_estado[df_dados_estado['estado']==estado][['casosAcumulado', 'obitosAcumulado', 'data']].plot()
    cod = str(df_cod_estados[df_cod_estados['estado']==estado]['coduf'].item())
    qtd = df_leitos_internacao[df_leitos_internacao['cod']==cod]['qtd'].item()
    df.axhline(y=qtd)
# Out:
# /home/dillenburg/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# /home/dillenburg/.local/lib/python3.6/site-packages/pandas/plotting/_matplotlib/core.py:320: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = self.plt.figure(figsize=self.figsize)
# ...
